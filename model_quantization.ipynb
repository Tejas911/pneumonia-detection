# %% [markdown]
# ## Post-Training QuantizationPost-Training Quantization

# %%
import tensorflow as tf

# Load the pre-trained model
model = tf.keras.models.load_model('merged_model.h5')

# Convert the model to TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the converted model
with open('quantized_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# INFO:tensorflow:Assets written to: C:\Users\Tejas\AppData\Local\Temp\tmp50a249wk\assets
# INFO:tensorflow:Assets written to: C:\Users\Tejas\AppData\Local\Temp\tmp50a249wk\assets
# Saved artifact at 'C:\Users\Tejas\AppData\Local\Temp\tmp50a249wk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   1447135290448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578469456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578470992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578461200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578469264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578470032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578472912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578470224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578473104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578470800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578471760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578472144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578468304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578468688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578473296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578472528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578467152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578467536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578465232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578466192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578469072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578471376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578467920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578464464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578465616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578464656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578466000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578463312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578463696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578462160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578462928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578464848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1445578464080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382221072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382222032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382223376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382222224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382221840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382221264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382220880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382224144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382222992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382223952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382222608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382225296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382224912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382226448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382226064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382223760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382224528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382227600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382227216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382228752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382228368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382225680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382226832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382230672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382232592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382233744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382235664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382171728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382172112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382172304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382173264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382172880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382174416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382174032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382171920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382172496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382175568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382175184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382176720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382176336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382173648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382174800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382177872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382177488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382179024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382178640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382175952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382177104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382180176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382181328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382180944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382178256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382182480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382183632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382183248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382181712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382185936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382182864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382184016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382368336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382372752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382371216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382373904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382375440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382375056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382372368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382376592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382376208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382377744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382377360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382374672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382375824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382378896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382378512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382380048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382379664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382376976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382378128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382381200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382380816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382382352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382381968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382379280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382380432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382383504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382383120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381696592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381696976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382383888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447382381584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381697744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381697360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381698896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381698512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381696784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381700048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381699664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381701200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381700816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381698128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381699280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381702352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381701968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381703504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381703120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381700432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381701584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381704656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381704272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381705808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381705424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381702736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381703888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381706960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381706576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381708112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381707728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381705040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381706192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381709264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381708880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381710416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381710032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381707344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381708496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381711568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381711184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293059728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293059536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447381709648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293060112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293059920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293061264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293060880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293059152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293059344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293062416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293062032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293064720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293063568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293063184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293060496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293061648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293065488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293064336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293065296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293063952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293066640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293066256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293067792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293067408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293065104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293065872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293068944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293068560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293070096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293069712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293067024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293068176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293071248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293071824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293071632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1447293072592: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import tensorflow as tf
from tensorflow.keras.applications import Xception
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load and preprocess the dataset for testing
test_datagen = ImageDataGenerator(rescale=1.0/255.0)

test_generator = test_datagen.flow_from_directory(
    r"split_chest_xray\test",  # Replace with the path to your testing dataset directory
    target_size=(224, 224),
    # batch_size=32,
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 624 images belonging to 2 classes.

# %%
model3 = tf.keras.models.load_model('merged_model.h5')
model3.compile(optimizer='adam',  # or your preferred optimizer
               loss='categorical_crossentropy',  # or your preferred loss function
               metrics=['accuracy'])  # or your preferred metrics
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# Evaluate the model on the testing data
test_loss, test_accuracy = model3.evaluate(test_generator)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# c:\Users\Tejas\OneDrive\Desktop\T_work\1. Projects\A.I\CNN Project\myenv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.8864 - loss: 0.3755
# Test Loss: 0.3796601891517639, Test Accuracy: 0.8894230723381042
